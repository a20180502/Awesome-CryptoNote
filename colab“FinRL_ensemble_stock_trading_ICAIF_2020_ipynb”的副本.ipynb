# %% [markdown]
# <a href="https://colab.research.google.com/github/a20180502/Awesome-CryptoNote/blob/master/colab%E2%80%9CFinRL_ensemble_stock_trading_ICAIF_2020_ipynb%E2%80%9D%E7%9A%84%E5%89%AF%E6%9C%AC.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
import os
drive.mount('/content/drive')
os.chdir("/content/drive/My Drive/ColabNotebooks/myFinRL")
# !pip install -r requirements.txt

# %% [markdown]
# # Deep Reinforcement Learning for Stock Trading from Scratch: Multiple Stock Trading Using Ensemble Strategy
#
# Tutorials to use OpenAI DRL to trade multiple stocks using ensemble strategy in one Jupyter Notebook | Presented at ICAIF 2020
#
# * This notebook is the reimplementation of our paper: Deep Reinforcement Learning for Automated Stock Trading: An Ensemble Strategy, using FinRL.
# * Check out medium blog for detailed explanations: https://medium.com/@ai4finance/deep-reinforcement-learning-for-automated-stock-trading-f1dad0126a02
# * Please report any issues to our Github: https://github.com/AI4Finance-LLC/FinRL-Library/issues
# * **Pytorch Version**

# %% [markdown]
# # Content

# %% [markdown]
# * [1. Problem Definition](#0)
# * [2. Getting Started - Load Python packages](#1)
#     * [2.1. Install Packages](#1.1)
#     * [2.2. Check Additional Packages](#1.2)
#     * [2.3. Import Packages](#1.3)
#     * [2.4. Create Folders](#1.4)
# * [3. Download Data](#2)
# * [4. Preprocess Data](#3)
#     * [4.1. Technical Indicators](#3.1)
#     * [4.2. Perform Feature Engineering](#3.2)
# * [5.Build Environment](#4)
#     * [5.1. Training & Trade Data Split](#4.1)
#     * [5.2. User-defined Environment](#4.2)
#     * [5.3. Initialize Environment](#4.3)
# * [6.Implement DRL Algorithms](#5)
# * [7.Backtesting Performance](#6)
#     * [7.1. BackTestStats](#6.1)
#     * [7.2. BackTestPlot](#6.2)
#     * [7.3. Baseline Stats](#6.3)
#     * [7.3. Compare to Stock Market Index](#6.4)

# %% [markdown]
# <a id='0'></a>
# # Part 1. Problem Definition

# %% [markdown]
# This problem is to design an automated trading solution for single stock trading. We model the stock trading process as a Markov Decision Process (MDP). We then formulate our trading goal as a maximization problem.
#
# The algorithm is trained using Deep Reinforcement Learning (DRL) algorithms and the components of the reinforcement learning environment are:
#
#
# * Action: The action space describes the allowed actions that the agent interacts with the
# environment. Normally, a ∈ A includes three actions: a ∈ {−1, 0, 1}, where −1, 0, 1 represent
# selling, holding, and buying one stock. Also, an action can be carried upon multiple shares. We use
# an action space {−k, ..., −1, 0, 1, ..., k}, where k denotes the number of shares. For example, "Buy
# 10 shares of AAPL" or "Sell 10 shares of AAPL" are 10 or −10, respectively
#
# * Reward function: r(s, a, s′) is the incentive mechanism for an agent to learn a better action. The change of the portfolio value when action a is taken at state s and arriving at new state s',  i.e., r(s, a, s′) = v′ − v, where v′ and v represent the portfolio
# values at state s′ and s, respectively
#
# * State: The state space describes the observations that the agent receives from the environment. Just as a human trader needs to analyze various information before executing a trade, so
# our trading agent observes many different features to better learn in an interactive environment.
#
# * Environment: Dow 30 consituents
#
#
# The data of the single stock that we will be using for this case study is obtained from Yahoo Finance API. The data contains Open-High-Low-Close price and volume.

# %% [markdown]
# <a id='1'></a>
# # Part 2. Getting Started- Load Python Packages

# %% [markdown]
# <a id='1.1'></a>
# ## 2.1. Install all the packages through FinRL library

# %%
#!git clone https://github.com/AI4Finance-LLC/FinRL ./myFinRL
# Out:
# Cloning into './myFinRL'...
# remote: Enumerating objects: 3408, done.
# remote: Counting objects: 100% (124/124), done.
# remote: Compressing objects: 100% (103/103), done.
# remote: Total 3408 (delta 80), reused 34 (delta 21), pack-reused 3284
# Receiving objects: 100% (3408/3408), 38.07 MiB | 13.11 MiB/s, done.
# Resolving deltas: 100% (2034/2034), done.

# %%
# ## install finrl library
#!pip install -target=/content/drive/MyDrive/Colab Notebooks git+https://github.com/AI4Finance-LLC/FinRL-Library.git .
# Out:
# ERROR: Directory '.' is not installable. Neither 'setup.py' nor 'pyproject.toml' found.

# %% [markdown]
# <a id='1.2'></a>
# ## 2.2. Check if the additional packages needed are present, if not install them.
# * Yahoo Finance API
# * pandas
# * numpy
# * matplotlib
# * stockstats
# * OpenAI gym
# * stable-baselines
# * tensorflow
# * pyfolio

# %% [markdown]
# <a id='1.3'></a>
# ## 2.3. Import Packages

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
# !pip install pyfolio

# %%
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
# matplotlib.use('Agg')
import datetime

# %matplotlib inline
from finrl.apps import config
from finrl.neo_finrl.preprocessor.yahoodownloader import YahooDownloader
from finrl.neo_finrl.preprocessor.preprocessors import FeatureEngineer, data_split
from finrl.neo_finrl.env_stock_trading.env_stocktrading import StockTradingEnv
from finrl.drl_agents.stablebaselines3.models import DRLAgent,DRLEnsembleAgent
from finrl.plot import backtest_stats, backtest_plot, get_daily_return, get_baseline

from pprint import pprint

import sys
sys.path.append("../FinRL-Library")

import itertools

# %% [markdown]
# <a id='1.4'></a>
# ## 2.4. Create Folders

# %%
import os
if not os.path.exists("./" + config.DATA_SAVE_DIR):
    os.makedirs("./" + config.DATA_SAVE_DIR)
if not os.path.exists("./" + config.TRAINED_MODEL_DIR):
    os.makedirs("./" + config.TRAINED_MODEL_DIR)
if not os.path.exists("./" + config.TENSORBOARD_LOG_DIR):
    os.makedirs("./" + config.TENSORBOARD_LOG_DIR)
if not os.path.exists("./" + config.RESULTS_DIR):
    os.makedirs("./" + config.RESULTS_DIR)

# %% [markdown]
# <a id='2'></a>
# # Part 3. Download Data
# Yahoo Finance is a website that provides stock data, financial news, financial reports, etc. All the data provided by Yahoo Finance is free.
# * FinRL uses a class **YahooDownloader** to fetch data from Yahoo Finance API
# * Call Limit: Using the Public API (without authentication), you are limited to 2,000 requests per hour per IP (or up to a total of 48,000 requests a day).

# %% [markdown]
# -----
# class YahooDownloader:
#     Provides methods for retrieving daily stock data from
#     Yahoo Finance API
#
#     Attributes
#     ----------
#         start_date : str
#             start date of the data (modified from config.py)
#         end_date : str
#             end date of the data (modified from config.py)
#         ticker_list : list
#             a list of stock tickers (modified from config.py)
#
#     Methods
#     -------
#     fetch_data()
#         Fetches data from yahoo API

# %%
# from config.py start_date is a string
config.START_DATE
# Out:
# '2009-01-01'

# %%
print(config.DOW_30_TICKER)
# Out:
# ['AAPL', 'MSFT', 'JPM', 'V', 'RTX', 'PG', 'GS', 'NKE', 'DIS', 'AXP', 'HD', 'INTC', 'WMT', 'IBM', 'MRK', 'UNH', 'KO', 'CAT', 'TRV', 'JNJ', 'CVX', 'MCD', 'VZ', 'CSCO', 'XOM', 'BA', 'MMM', 'PFE', 'WBA', 'DD']

# %%
df = YahooDownloader(start_date = '2009-01-01',
                     end_date = '2021-08-22',
                     ticker_list = config.DOW_30_TICKER).fetch_data()
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# Shape of DataFrame:  (95430, 8)

# %%
df.head()
# Out:
#          date       open       high        low      close     volume   tic  day
# 0  2009-01-02   3.067143   3.251429   3.041429   2.782837  746015200  AAPL    4
# 1  2009-01-02  18.570000  19.520000  18.400000  15.657365   10955700   AXP    4
# 2  2009-01-02  42.799999  45.560001  42.779999  33.941101    7010200    BA    4
# 3  2009-01-02  44.910000  46.980000  44.709999  32.655109    7117200   CAT    4
# 4  2009-01-02  16.410000  17.000000  16.250000  12.505757   40980600  CSCO    4

# %%
df.tail()
# Out:
#              date        open        high  ...    volume  tic  day
# 95425  2021-08-20  231.869995  232.160004  ...   5522200    V    4
# 95426  2021-08-20   55.330002   55.709999  ...  10641100   VZ    4
# 95427  2021-08-20   47.500000   48.360001  ...   3285100  WBA    4
# 95428  2021-08-20  150.479996  151.720001  ...   6465300  WMT    4
# 95429  2021-08-20   52.270000   53.139999  ...  16915300  XOM    4
#
# [5 rows x 8 columns]

# %%
df.shape
# Out:
# (95430, 8)

# %%
df.sort_values(['date','tic']).head()
# Out:
#          date       open       high        low      close     volume   tic  day
# 0  2009-01-02   3.067143   3.251429   3.041429   2.782837  746015200  AAPL    4
# 1  2009-01-02  18.570000  19.520000  18.400000  15.657365   10955700   AXP    4
# 2  2009-01-02  42.799999  45.560001  42.779999  33.941101    7010200    BA    4
# 3  2009-01-02  44.910000  46.980000  44.709999  32.655109    7117200   CAT    4
# 4  2009-01-02  16.410000  17.000000  16.250000  12.505757   40980600  CSCO    4

# %%
len(df.tic.unique())
# Out:
# 30

# %%
df.tic.value_counts()
# Out:
# MMM     3181
# PG      3181
# GS      3181
# UNH     3181
# MRK     3181
# JNJ     3181
# CAT     3181
# JPM     3181
# WMT     3181
# RTX     3181
# NKE     3181
# VZ      3181
# MCD     3181
# IBM     3181
# AAPL    3181
# KO      3181
# WBA     3181
# DD      3181
# TRV     3181
# CVX     3181
# PFE     3181
# AXP     3181
# V       3181
# HD      3181
# INTC    3181
# BA      3181
# MSFT    3181
# XOM     3181
# CSCO    3181
# DIS     3181
# Name: tic, dtype: int64

# %% [markdown]
# # Part 4: Preprocess Data
# Data preprocessing is a crucial step for training a high quality machine learning model. We need to check for missing data and do feature engineering in order to convert the data into a model-ready state.
# * Add technical indicators. In practical trading, various information needs to be taken into account, for example the historical stock prices, current holding shares, technical indicators, etc. In this article, we demonstrate two trend-following technical indicators: MACD and RSI.
# * Add turbulence index. Risk-aversion reflects whether an investor will choose to preserve the capital. It also influences one's trading strategy when facing different market volatility level. To control the risk in a worst-case scenario, such as financial crisis of 2007–2008, FinRL employs the financial turbulence index that measures extreme asset price fluctuation.

# %%
tech_indicators = ['macd',
 'rsi_30',
 'cci_30',
 'dx_30']

# %%
fe = FeatureEngineer(
                    use_technical_indicator=True,
                    tech_indicator_list = tech_indicators,
                    use_turbulence=True,
                    user_defined_feature = False)

processed = fe.preprocess_data(df)
# Out:
# Successfully added technical indicators
# Successfully added turbulence index

# %%
processed.sample(5)
# Out:
#              date        open        high  ...      cci_30      dx_30  turbulence
# 36862  2013-11-18   68.344872   69.169289  ...  161.012445   6.580516   22.706830
# 22959  2012-01-17   43.610001   43.959999  ...  118.511005  49.056443   23.214696
# 5137   2009-09-08   26.309999   26.360001  ...   32.063473   8.297002    0.000000
# 58888  2016-10-18   68.570000   68.980003  ...  -97.052524  27.554694  121.169297
# 71559  2018-06-25  197.410004  197.839996  ...   46.013114  17.197134   47.027829
#
# [5 rows x 13 columns]

# %% [markdown]
# <a id='4'></a>
# # Part 5. Design Environment
# Considering the stochastic and interactive nature of the automated stock trading tasks, a financial task is modeled as a **Markov Decision Process (MDP)** problem. The training process involves observing stock price change, taking an action and reward's calculation to have the agent adjusting its strategy accordingly. By interacting with the environment, the trading agent will derive a trading strategy with the maximized rewards as time proceeds.
#
# Our trading environments, based on OpenAI Gym framework, simulate live stock markets with real market data according to the principle of time-driven simulation.
#
# The action space describes the allowed actions that the agent interacts with the environment. Normally, action a includes three actions: {-1, 0, 1}, where -1, 0, 1 represent selling, holding, and buying one share. Also, an action can be carried upon multiple shares. We use an action space {-k,…,-1, 0, 1, …, k}, where k denotes the number of shares to buy and -k denotes the number of shares to sell. For example, "Buy 10 shares of AAPL" or "Sell 10 shares of AAPL" are 10 or -10, respectively. The continuous action space needs to be normalized to [-1, 1], since the policy is defined on a Gaussian distribution, which needs to be normalized and symmetric.

# %%
stock_dimension = len(processed.tic.unique())
state_space = 1 + 2*stock_dimension + len(tech_indicators)*stock_dimension
print(f"Stock Dimension: {stock_dimension}, State Space: {state_space}")
# Out:
# Stock Dimension: 30, State Space: 181

# %%
env_kwargs = {
    "hmax": 100, 
    "initial_amount": 1000000, 
    "buy_cost_pct": 0.001, 
    "sell_cost_pct": 0.001, 
    "state_space": state_space, 
    "stock_dim": stock_dimension, 
    "tech_indicator_list": tech_indicators,
    "action_space": stock_dimension, 
    "reward_scaling": 1e-4,
    "print_verbosity":5
    
}

# %% [markdown]
# <a id='5'></a>
# # Part 6: Implement DRL Algorithms
# * The implementation of the DRL algorithms are based on **OpenAI Baselines** and **Stable Baselines**. Stable Baselines is a fork of OpenAI Baselines, with a major structural refactoring, and code cleanups.
# * FinRL library includes fine-tuned standard DRL algorithms, such as DQN, DDPG,
# Multi-Agent DDPG, PPO, SAC, A2C and TD3. We also allow users to
# design their own DRL algorithms by adapting these DRL algorithms.
#
# * In this notebook, we are training and validating 3 agents (A2C, PPO, DDPG) using Rolling-window Ensemble Method ([reference code](https://github.com/AI4Finance-LLC/Deep-Reinforcement-Learning-for-Automated-Stock-Trading-Ensemble-Strategy-ICAIF-2020/blob/80415db8fa7b2179df6bd7e81ce4fe8dbf913806/model/models.py#L92))

# %%
rebalance_window = 63 # rebalance_window is the number of days to retrain the model
validation_window = 63 # validation_window is the number of days to do validation and trading (e.g. if validation_window=63, then both validation and trading period will be 63 days)
train_start = '2009-01-01'
train_end = '2020-04-01'
val_test_start = '2020-04-01'
val_test_end = '2021-08-22'

ensemble_agent = DRLEnsembleAgent(df=processed,
                 train_period=(train_start,train_end),
                 val_test_period=(val_test_start,val_test_end),
                 rebalance_window=rebalance_window, 
                 validation_window=validation_window, 
                 **env_kwargs)

# %%
A2C_model_kwargs = {
                    'n_steps': 5,
                    'ent_coef': 0.01,
                    'learning_rate': 0.0005
                    }

PPO_model_kwargs = {
                    "ent_coef":0.01,
                    "n_steps": 2048,
                    "learning_rate": 0.00025,
                    "batch_size": 64
                    }

DDPG_model_kwargs = {
                      #"action_noise":"ornstein_uhlenbeck",
                      "buffer_size": 100_000,
                      "learning_rate": 0.000005,
                      "batch_size": 64
                    }

timesteps_dict = {'a2c' : 30_000, 
                 'ppo' : 100_000, 
                 'ddpg' : 10_000
                 }


timesteps_dict = {'a2c' : 10_000, 
                 'ppo' : 10_000, 
                 'ddpg' : 10_000
                 }

# %%
df_summary = ensemble_agent.run_ensemble_strategy(A2C_model_kwargs,
                                                 PPO_model_kwargs,
                                                 DDPG_model_kwargs,
                                                 timesteps_dict)
# Out:
# ============Start Ensemble Strategy============
# ============================================
# turbulence_threshold:  208.116244054249
# ======Model training from:  2009-01-01 to  2020-04-02
# ======A2C Training========
# {'n_steps': 5, 'ent_coef': 0.01, 'learning_rate': 0.0005}
# Using cpu device
# Logging to tensorboard_log/a2c/a2c_126_1
# ------------------------------------
# | time/                 |          |
# |    fps                | 76       |
# |    iterations         | 100      |
# |    time_elapsed       | 6        |
# |    total_timesteps    | 500      |
# | train/                |          |
# |    entropy_loss       | -42.6    |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 99       |
# |    policy_loss        | -36      |
# |    std                | 1        |
# |    value_loss         | 0.908    |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 87       |
# |    iterations         | 200      |
# |    time_elapsed       | 11       |
# |    total_timesteps    | 1000     |
# | train/                |          |
# |    entropy_loss       | -42.6    |
# |    explained_variance | 0.331    |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 199      |
# |    policy_loss        | -2.88    |
# |    std                | 1        |
# |    value_loss         | 0.147    |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 91       |
# |    iterations         | 300      |
# |    time_elapsed       | 16       |
# |    total_timesteps    | 1500     |
# | train/                |          |
# |    entropy_loss       | -42.6    |
# |    explained_variance | 0.0647   |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 299      |
# |    policy_loss        | -177     |
# |    std                | 1        |
# |    value_loss         | 14.5     |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 94       |
# |    iterations         | 400      |
# |    time_elapsed       | 21       |
# |    total_timesteps    | 2000     |
# | train/                |          |
# |    entropy_loss       | -42.7    |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 399      |
# |    policy_loss        | 27       |
# |    std                | 1        |
# |    value_loss         | 0.832    |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 95       |
# |    iterations         | 500      |
# |    time_elapsed       | 26       |
# |    total_timesteps    | 2500     |
# | train/                |          |
# |    entropy_loss       | -42.6    |
# |    explained_variance | -0.026   |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 499      |
# |    policy_loss        | 247      |
# |    std                | 1        |
# |    value_loss         | 52.3     |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 96       |
# |    iterations         | 600      |
# |    time_elapsed       | 31       |
# |    total_timesteps    | 3000     |
# | train/                |          |
# |    entropy_loss       | -42.6    |
# |    explained_variance | -0.291   |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 599      |
# |    policy_loss        | 16.6     |
# |    std                | 1        |
# |    value_loss         | 0.876    |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 97       |
# |    iterations         | 700      |
# |    time_elapsed       | 35       |
# |    total_timesteps    | 3500     |
# | train/                |          |
# |    entropy_loss       | -42.6    |
# |    explained_variance | -0.0383  |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 699      |
# |    policy_loss        | -134     |
# |    std                | 1        |
# |    value_loss         | 17.3     |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 98       |
# |    iterations         | 800      |
# |    time_elapsed       | 40       |
# |    total_timesteps    | 4000     |
# | train/                |          |
# |    entropy_loss       | -42.6    |
# |    explained_variance | -0.0895  |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 799      |
# |    policy_loss        | -168     |
# |    std                | 1        |
# |    value_loss         | 19.9     |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 98       |
# |    iterations         | 900      |
# |    time_elapsed       | 45       |
# |    total_timesteps    | 4500     |
# | train/                |          |
# |    entropy_loss       | -42.6    |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 899      |
# |    policy_loss        | -12      |
# |    std                | 1        |
# |    value_loss         | 0.859    |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 98       |
# |    iterations         | 1000     |
# |    time_elapsed       | 50       |
# |    total_timesteps    | 5000     |
# | train/                |          |
# |    entropy_loss       | -42.6    |
# |    explained_variance | 0.231    |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 999      |
# |    policy_loss        | -27.7    |
# |    std                | 1        |
# |    value_loss         | 0.508    |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 98       |
# |    iterations         | 1100     |
# |    time_elapsed       | 55       |
# |    total_timesteps    | 5500     |
# | train/                |          |
# |    entropy_loss       | -42.6    |
# |    explained_variance | 1.19e-07 |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 1099     |
# |    policy_loss        | -384     |
# |    std                | 1        |
# |    value_loss         | 95.7     |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 99       |
# |    iterations         | 1200     |
# |    time_elapsed       | 60       |
# |    total_timesteps    | 6000     |
# | train/                |          |
# |    entropy_loss       | -42.7    |
# |    explained_variance | 0.0477   |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 1199     |
# |    policy_loss        | -142     |
# |    std                | 1        |
# |    value_loss         | 11.3     |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 99       |
# |    iterations         | 1300     |
# |    time_elapsed       | 65       |
# |    total_timesteps    | 6500     |
# | train/                |          |
# |    entropy_loss       | -42.6    |
# |    explained_variance | -0.0519  |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 1299     |
# |    policy_loss        | 15.9     |
# |    std                | 1        |
# |    value_loss         | 0.462    |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 99       |
# |    iterations         | 1400     |
# |    time_elapsed       | 70       |
# |    total_timesteps    | 7000     |
# | train/                |          |
# |    entropy_loss       | -42.7    |
# |    explained_variance | 0.0866   |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 1399     |
# |    policy_loss        | 75.8     |
# |    std                | 1        |
# |    value_loss         | 7.38     |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 99       |
# |    iterations         | 1500     |
# |    time_elapsed       | 75       |
# |    total_timesteps    | 7500     |
# | train/                |          |
# |    entropy_loss       | -42.6    |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 1499     |
# |    policy_loss        | -31.1    |
# |    std                | 1        |
# |    value_loss         | 2.51     |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 100      |
# |    iterations         | 1600     |
# |    time_elapsed       | 79       |
# |    total_timesteps    | 8000     |
# | train/                |          |
# |    entropy_loss       | -42.7    |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 1599     |
# |    policy_loss        | -15.9    |
# |    std                | 1        |
# |    value_loss         | 1.35     |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 100      |
# |    iterations         | 1700     |
# |    time_elapsed       | 84       |
# |    total_timesteps    | 8500     |
# | train/                |          |
# |    entropy_loss       | -42.7    |
# |    explained_variance | -0.298   |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 1699     |
# |    policy_loss        | -694     |
# |    std                | 1.01     |
# |    value_loss         | 422      |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 100      |
# |    iterations         | 1800     |
# |    time_elapsed       | 89       |
# |    total_timesteps    | 9000     |
# | train/                |          |
# |    entropy_loss       | -42.8    |
# |    explained_variance | 0.112    |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 1799     |
# |    policy_loss        | -23.1    |
# |    std                | 1.01     |
# |    value_loss         | 0.389    |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 100      |
# |    iterations         | 1900     |
# |    time_elapsed       | 94       |
# |    total_timesteps    | 9500     |
# | train/                |          |
# |    entropy_loss       | -42.8    |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 1899     |
# |    policy_loss        | -86.5    |
# |    std                | 1.01     |
# |    value_loss         | 4.47     |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 100      |
# |    iterations         | 2000     |
# |    time_elapsed       | 99       |
# |    total_timesteps    | 10000    |
# | train/                |          |
# |    entropy_loss       | -42.8    |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 1999     |
# |    policy_loss        | 186      |
# |    std                | 1.01     |
# |    value_loss         | 32.7     |
# ------------------------------------
# ======A2C Validation from:  2020-04-02 to  2020-07-02
# A2C Sharpe Ratio:  0.1681249183351536
# ======PPO Training========
# {'ent_coef': 0.01, 'n_steps': 2048, 'learning_rate': 0.00025, 'batch_size': 64}
# Using cpu device
# Logging to tensorboard_log/ppo/ppo_126_1
# -----------------------------
# | time/              |      |
# |    fps             | 109  |
# |    iterations      | 1    |
# |    time_elapsed    | 18   |
# |    total_timesteps | 2048 |
# -----------------------------
# day: 2830, episode: 5
# begin_total_asset: 1000000.00
# end_total_asset: 2716780.44
# total_reward: 1716780.44
# total_cost: 336598.13
# total_trades: 81835
# Sharpe: 0.627
# =================================
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 106         |
# |    iterations           | 2           |
# |    time_elapsed         | 38          |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.020185456 |
# |    clip_fraction        | 0.255       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -42.6       |
# |    explained_variance   | -0.00702    |
# |    learning_rate        | 0.00025     |
# |    loss                 | 4.73        |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.0335     |
# |    std                  | 1           |
# |    value_loss           | 13.6        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 105         |
# |    iterations           | 3           |
# |    time_elapsed         | 58          |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.020841345 |
# |    clip_fraction        | 0.238       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -42.7       |
# |    explained_variance   | 0.00218     |
# |    learning_rate        | 0.00025     |
# |    loss                 | 28.9        |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.0222     |
# |    std                  | 1.01        |
# |    value_loss           | 72.2        |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 105        |
# |    iterations           | 4          |
# |    time_elapsed         | 77         |
# |    total_timesteps      | 8192       |
# | train/                  |            |
# |    approx_kl            | 0.02040929 |
# |    clip_fraction        | 0.246      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -42.8      |
# |    explained_variance   | 0.0148     |
# |    learning_rate        | 0.00025    |
# |    loss                 | 58.2       |
# |    n_updates            | 30         |
# |    policy_gradient_loss | -0.0214    |
# |    std                  | 1.01       |
# |    value_loss           | 45.9       |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 104         |
# |    iterations           | 5           |
# |    time_elapsed         | 97          |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.029088553 |
# |    clip_fraction        | 0.302       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -42.8       |
# |    explained_variance   | -0.0216     |
# |    learning_rate        | 0.00025     |
# |    loss                 | 4.59        |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.0241     |
# |    std                  | 1.01        |
# |    value_loss           | 15          |
# -----------------------------------------
# ======PPO Validation from:  2020-04-02 to  2020-07-02
# PPO Sharpe Ratio:  0.04295793230241467
# ======DDPG Training========
# {'buffer_size': 100000, 'learning_rate': 5e-06, 'batch_size': 64}
# Using cpu device
# Logging to tensorboard_log/ddpg/ddpg_126_1
# day: 2830, episode: 10
# begin_total_asset: 1000000.00
# end_total_asset: 3197134.43
# total_reward: 2197134.43
# total_cost: 1973.86
# total_trades: 38582
# Sharpe: 0.726
# =================================
# ---------------------------------
# | time/              |          |
# |    episodes        | 4        |
# |    fps             | 55       |
# |    time_elapsed    | 203      |
# |    total timesteps | 11324    |
# | train/             |          |
# |    actor_loss      | -39.3    |
# |    critic_loss     | 45.2     |
# |    learning_rate   | 5e-06    |
# |    n_updates       | 8493     |
# ---------------------------------
# ======DDPG Validation from:  2020-04-02 to  2020-07-02
# ======Best Model Retraining from:  2009-01-01 to  2020-07-02
# ======Trading from:  2020-07-02 to  2020-10-01
# ============================================
# turbulence_threshold:  208.116244054249
# ======Model training from:  2009-01-01 to  2020-07-02
# ======A2C Training========
# {'n_steps': 5, 'ent_coef': 0.01, 'learning_rate': 0.0005}
# Using cpu device
# Logging to tensorboard_log/a2c/a2c_189_1
# ------------------------------------
# | time/                 |          |
# |    fps                | 99       |
# |    iterations         | 100      |
# |    time_elapsed       | 5        |
# |    total_timesteps    | 500      |
# | train/                |          |
# |    entropy_loss       | -42.8    |
# |    explained_variance | 0.0187   |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 99       |
# |    policy_loss        | -67.2    |
# |    std                | 1.01     |
# |    value_loss         | 3.23     |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 98        |
# |    iterations         | 200       |
# |    time_elapsed       | 10        |
# |    total_timesteps    | 1000      |
# | train/                |           |
# |    entropy_loss       | -42.9     |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0005    |
# |    n_updates          | 199       |
# |    policy_loss        | -73.8     |
# |    std                | 1.01      |
# |    value_loss         | 3.34      |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 99       |
# |    iterations         | 300      |
# |    time_elapsed       | 15       |
# |    total_timesteps    | 1500     |
# | train/                |          |
# |    entropy_loss       | -42.8    |
# |    explained_variance | 0.169    |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 299      |
# |    policy_loss        | -232     |
# |    std                | 1.01     |
# |    value_loss         | 32.3     |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 99       |
# |    iterations         | 400      |
# |    time_elapsed       | 20       |
# |    total_timesteps    | 2000     |
# | train/                |          |
# |    entropy_loss       | -42.9    |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 399      |
# |    policy_loss        | 30       |
# |    std                | 1.01     |
# |    value_loss         | 5.89     |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 99       |
# |    iterations         | 500      |
# |    time_elapsed       | 25       |
# |    total_timesteps    | 2500     |
# | train/                |          |
# |    entropy_loss       | -42.9    |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 499      |
# |    policy_loss        | 377      |
# |    std                | 1.01     |
# |    value_loss         | 126      |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 99        |
# |    iterations         | 600       |
# |    time_elapsed       | 30        |
# |    total_timesteps    | 3000      |
# | train/                |           |
# |    entropy_loss       | -42.9     |
# |    explained_variance | -3.58e-07 |
# |    learning_rate      | 0.0005    |
# |    n_updates          | 599       |
# |    policy_loss        | 57.3      |
# |    std                | 1.01      |
# |    value_loss         | 2.04      |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 99       |
# |    iterations         | 700      |
# |    time_elapsed       | 35       |
# |    total_timesteps    | 3500     |
# | train/                |          |
# |    entropy_loss       | -42.9    |
# |    explained_variance | -0.73    |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 699      |
# |    policy_loss        | -35.4    |
# |    std                | 1.01     |
# |    value_loss         | 0.998    |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 99       |
# |    iterations         | 800      |
# |    time_elapsed       | 40       |
# |    total_timesteps    | 4000     |
# | train/                |          |
# |    entropy_loss       | -42.9    |
# |    explained_variance | -0.385   |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 799      |
# |    policy_loss        | 54.4     |
# |    std                | 1.01     |
# |    value_loss         | 5.07     |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 99       |
# |    iterations         | 900      |
# |    time_elapsed       | 45       |
# |    total_timesteps    | 4500     |
# | train/                |          |
# |    entropy_loss       | -43      |
# |    explained_variance | -0.0154  |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 899      |
# |    policy_loss        | 122      |
# |    std                | 1.01     |
# |    value_loss         | 11.1     |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 99       |
# |    iterations         | 1000     |
# |    time_elapsed       | 50       |
# |    total_timesteps    | 5000     |
# | train/                |          |
# |    entropy_loss       | -43      |
# |    explained_variance | 0.0329   |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 999      |
# |    policy_loss        | -0.871   |
# |    std                | 1.01     |
# |    value_loss         | 0.0445   |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 99       |
# |    iterations         | 1100     |
# |    time_elapsed       | 55       |
# |    total_timesteps    | 5500     |
# | train/                |          |
# |    entropy_loss       | -43      |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 1099     |
# |    policy_loss        | -59.5    |
# |    std                | 1.01     |
# |    value_loss         | 18.7     |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 99       |
# |    iterations         | 1200     |
# |    time_elapsed       | 60       |
# |    total_timesteps    | 6000     |
# | train/                |          |
# |    entropy_loss       | -43      |
# |    explained_variance | 0.0323   |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 1199     |
# |    policy_loss        | -91.2    |
# |    std                | 1.02     |
# |    value_loss         | 5.18     |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 99       |
# |    iterations         | 1300     |
# |    time_elapsed       | 65       |
# |    total_timesteps    | 6500     |
# | train/                |          |
# |    entropy_loss       | -43      |
# |    explained_variance | 1.19e-07 |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 1299     |
# |    policy_loss        | 132      |
# |    std                | 1.02     |
# |    value_loss         | 9.61     |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 99       |
# |    iterations         | 1400     |
# |    time_elapsed       | 70       |
# |    total_timesteps    | 7000     |
# | train/                |          |
# |    entropy_loss       | -43      |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 1399     |
# |    policy_loss        | 61.7     |
# |    std                | 1.02     |
# |    value_loss         | 2.26     |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 99       |
# |    iterations         | 1500     |
# |    time_elapsed       | 75       |
# |    total_timesteps    | 7500     |
# | train/                |          |
# |    entropy_loss       | -43      |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 1499     |
# |    policy_loss        | 53.5     |
# |    std                | 1.01     |
# |    value_loss         | 3.2      |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 99       |
# |    iterations         | 1600     |
# |    time_elapsed       | 80       |
# |    total_timesteps    | 8000     |
# | train/                |          |
# |    entropy_loss       | -43      |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 1599     |
# |    policy_loss        | -6.84    |
# |    std                | 1.02     |
# |    value_loss         | 0.277    |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 99       |
# |    iterations         | 1700     |
# |    time_elapsed       | 85       |
# |    total_timesteps    | 8500     |
# | train/                |          |
# |    entropy_loss       | -43.1    |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 1699     |
# |    policy_loss        | 15.8     |
# |    std                | 1.02     |
# |    value_loss         | 21.2     |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 99       |
# |    iterations         | 1800     |
# |    time_elapsed       | 90       |
# |    total_timesteps    | 9000     |
# | train/                |          |
# |    entropy_loss       | -43      |
# |    explained_variance | 0.384    |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 1799     |
# |    policy_loss        | -16.5    |
# |    std                | 1.02     |
# |    value_loss         | 0.265    |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 99       |
# |    iterations         | 1900     |
# |    time_elapsed       | 95       |
# |    total_timesteps    | 9500     |
# | train/                |          |
# |    entropy_loss       | -43      |
# |    explained_variance | -0.291   |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 1899     |
# |    policy_loss        | 73.6     |
# |    std                | 1.01     |
# |    value_loss         | 3.61     |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 99       |
# |    iterations         | 2000     |
# |    time_elapsed       | 100      |
# |    total_timesteps    | 10000    |
# | train/                |          |
# |    entropy_loss       | -43      |
# |    explained_variance | -0.303   |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 1999     |
# |    policy_loss        | -58.8    |
# |    std                | 1.01     |
# |    value_loss         | 2.81     |
# ------------------------------------
# ======A2C Validation from:  2020-07-02 to  2020-10-01
# A2C Sharpe Ratio:  0.08744667625747239
# ======PPO Training========
# {'ent_coef': 0.01, 'n_steps': 2048, 'learning_rate': 0.00025, 'batch_size': 64}
# Using cpu device
# Logging to tensorboard_log/ppo/ppo_189_1
# -----------------------------
# | time/              |      |
# |    fps             | 106  |
# |    iterations      | 1    |
# |    time_elapsed    | 19   |
# |    total_timesteps | 2048 |
# -----------------------------
# day: 2893, episode: 5
# begin_total_asset: 1000000.00
# end_total_asset: 2765715.74
# total_reward: 1765715.74
# total_cost: 343511.33
# total_trades: 83621
# Sharpe: 0.641
# =================================
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 103         |
# |    iterations           | 2           |
# |    time_elapsed         | 39          |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.017514817 |
# |    clip_fraction        | 0.246       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -42.6       |
# |    explained_variance   | -0.0142     |
# |    learning_rate        | 0.00025     |
# |    loss                 | 4.32        |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.0269     |
# |    std                  | 1           |
# |    value_loss           | 8.44        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 102         |
# |    iterations           | 3           |
# |    time_elapsed         | 59          |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.021003868 |
# |    clip_fraction        | 0.23        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -42.7       |
# |    explained_variance   | -0.00101    |
# |    learning_rate        | 0.00025     |
# |    loss                 | 12.7        |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.0215     |
# |    std                  | 1.01        |
# |    value_loss           | 30.1        |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 102        |
# |    iterations           | 4          |
# |    time_elapsed         | 80         |
# |    total_timesteps      | 8192       |
# | train/                  |            |
# |    approx_kl            | 0.01909079 |
# |    clip_fraction        | 0.179      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -42.8      |
# |    explained_variance   | -0.00572   |
# |    learning_rate        | 0.00025    |
# |    loss                 | 22.9       |
# |    n_updates            | 30         |
# |    policy_gradient_loss | -0.0166    |
# |    std                  | 1.01       |
# |    value_loss           | 95.1       |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 102         |
# |    iterations           | 5           |
# |    time_elapsed         | 100         |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.024507992 |
# |    clip_fraction        | 0.251       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -42.8       |
# |    explained_variance   | -0.0214     |
# |    learning_rate        | 0.00025     |
# |    loss                 | 14.2        |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.0243     |
# |    std                  | 1.01        |
# |    value_loss           | 27.2        |
# -----------------------------------------
# ======PPO Validation from:  2020-07-02 to  2020-10-01
# PPO Sharpe Ratio:  0.11408577752576474
# ======DDPG Training========
# {'buffer_size': 100000, 'learning_rate': 5e-06, 'batch_size': 64}
# Using cpu device
# Logging to tensorboard_log/ddpg/ddpg_189_1
# day: 2893, episode: 10
# begin_total_asset: 1000000.00
# end_total_asset: 4227799.01
# total_reward: 3227799.01
# total_cost: 2229.26
# total_trades: 46241
# Sharpe: 0.765
# =================================
# ---------------------------------
# | time/              |          |
# |    episodes        | 4        |
# |    fps             | 52       |
# |    time_elapsed    | 221      |
# |    total timesteps | 11576    |
# | train/             |          |
# |    actor_loss      | 183      |
# |    critic_loss     | 412      |
# |    learning_rate   | 5e-06    |
# |    n_updates       | 8682     |
# ---------------------------------
# ======DDPG Validation from:  2020-07-02 to  2020-10-01
# ======Best Model Retraining from:  2009-01-01 to  2020-10-01
# ======Trading from:  2020-10-01 to  2020-12-31
# ============================================
# turbulence_threshold:  208.116244054249
# ======Model training from:  2009-01-01 to  2020-10-01
# ======A2C Training========
# {'n_steps': 5, 'ent_coef': 0.01, 'learning_rate': 0.0005}
# Using cpu device
# Logging to tensorboard_log/a2c/a2c_252_1
# ------------------------------------
# | time/                 |          |
# |    fps                | 97       |
# |    iterations         | 100      |
# |    time_elapsed       | 5        |
# |    total_timesteps    | 500      |
# | train/                |          |
# |    entropy_loss       | -42.7    |
# |    explained_variance | 0.186    |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 99       |
# |    policy_loss        | -18.4    |
# |    std                | 1.01     |
# |    value_loss         | 0.292    |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 97       |
# |    iterations         | 200      |
# |    time_elapsed       | 10       |
# |    total_timesteps    | 1000     |
# | train/                |          |
# |    entropy_loss       | -42.7    |
# |    explained_variance | -0.0217  |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 199      |
# |    policy_loss        | -35.5    |
# |    std                | 1.01     |
# |    value_loss         | 1.27     |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 98       |
# |    iterations         | 300      |
# |    time_elapsed       | 15       |
# |    total_timesteps    | 1500     |
# | train/                |          |
# |    entropy_loss       | -42.7    |
# |    explained_variance | 8.33e-05 |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 299      |
# |    policy_loss        | -182     |
# |    std                | 1.01     |
# |    value_loss         | 21.4     |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 98       |
# |    iterations         | 400      |
# |    time_elapsed       | 20       |
# |    total_timesteps    | 2000     |
# | train/                |          |
# |    entropy_loss       | -42.7    |
# |    explained_variance | 0.0121   |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 399      |
# |    policy_loss        | 115      |
# |    std                | 1.01     |
# |    value_loss         | 8.15     |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 98       |
# |    iterations         | 500      |
# |    time_elapsed       | 25       |
# |    total_timesteps    | 2500     |
# | train/                |          |
# |    entropy_loss       | -42.7    |
# |    explained_variance | -0.0295  |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 499      |
# |    policy_loss        | 217      |
# |    std                | 1.01     |
# |    value_loss         | 36.6     |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 98       |
# |    iterations         | 600      |
# |    time_elapsed       | 30       |
# |    total_timesteps    | 3000     |
# | train/                |          |
# |    entropy_loss       | -42.8    |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 599      |
# |    policy_loss        | 4.27     |
# |    std                | 1.01     |
# |    value_loss         | 0.637    |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 98       |
# |    iterations         | 700      |
# |    time_elapsed       | 35       |
# |    total_timesteps    | 3500     |
# | train/                |          |
# |    entropy_loss       | -42.7    |
# |    explained_variance | 0.0589   |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 699      |
# |    policy_loss        | 46.1     |
# |    std                | 1.01     |
# |    value_loss         | 1.92     |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 98       |
# |    iterations         | 800      |
# |    time_elapsed       | 40       |
# |    total_timesteps    | 4000     |
# | train/                |          |
# |    entropy_loss       | -42.7    |
# |    explained_variance | -0.863   |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 799      |
# |    policy_loss        | 43       |
# |    std                | 1.01     |
# |    value_loss         | 1.45     |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 98       |
# |    iterations         | 900      |
# |    time_elapsed       | 45       |
# |    total_timesteps    | 4500     |
# | train/                |          |
# |    entropy_loss       | -42.7    |
# |    explained_variance | 0.0313   |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 899      |
# |    policy_loss        | 204      |
# |    std                | 1.01     |
# |    value_loss         | 20.3     |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 98       |
# |    iterations         | 1000     |
# |    time_elapsed       | 50       |
# |    total_timesteps    | 5000     |
# | train/                |          |
# |    entropy_loss       | -42.8    |
# |    explained_variance | -0.435   |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 999      |
# |    policy_loss        | -14.2    |
# |    std                | 1.01     |
# |    value_loss         | 0.482    |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 98       |
# |    iterations         | 1100     |
# |    time_elapsed       | 55       |
# |    total_timesteps    | 5500     |
# | train/                |          |
# |    entropy_loss       | -42.8    |
# |    explained_variance | -0.0551  |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 1099     |
# |    policy_loss        | 391      |
# |    std                | 1.01     |
# |    value_loss         | 118      |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 98       |
# |    iterations         | 1200     |
# |    time_elapsed       | 60       |
# |    total_timesteps    | 6000     |
# | train/                |          |
# |    entropy_loss       | -42.8    |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 1199     |
# |    policy_loss        | 74.9     |
# |    std                | 1.01     |
# |    value_loss         | 4.08     |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 98       |
# |    iterations         | 1300     |
# |    time_elapsed       | 65       |
# |    total_timesteps    | 6500     |
# | train/                |          |
# |    entropy_loss       | -42.8    |
# |    explained_variance | 0.0152   |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 1299     |
# |    policy_loss        | 14.3     |
# |    std                | 1.01     |
# |    value_loss         | 0.394    |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 98       |
# |    iterations         | 1400     |
# |    time_elapsed       | 70       |
# |    total_timesteps    | 7000     |
# | train/                |          |
# |    entropy_loss       | -42.8    |
# |    explained_variance | -0.49    |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 1399     |
# |    policy_loss        | 123      |
# |    std                | 1.01     |
# |    value_loss         | 8.88     |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 98       |
# |    iterations         | 1500     |
# |    time_elapsed       | 75       |
# |    total_timesteps    | 7500     |
# | train/                |          |
# |    entropy_loss       | -42.8    |
# |    explained_variance | 0.015    |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 1499     |
# |    policy_loss        | 58.8     |
# |    std                | 1.01     |
# |    value_loss         | 3.12     |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 98       |
# |    iterations         | 1600     |
# |    time_elapsed       | 80       |
# |    total_timesteps    | 8000     |
# | train/                |          |
# |    entropy_loss       | -42.8    |
# |    explained_variance | 0.0304   |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 1599     |
# |    policy_loss        | 30.1     |
# |    std                | 1.01     |
# |    value_loss         | 0.591    |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 98       |
# |    iterations         | 1700     |
# |    time_elapsed       | 85       |
# |    total_timesteps    | 8500     |
# | train/                |          |
# |    entropy_loss       | -42.8    |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 1699     |
# |    policy_loss        | 216      |
# |    std                | 1.01     |
# |    value_loss         | 35.5     |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 98       |
# |    iterations         | 1800     |
# |    time_elapsed       | 91       |
# |    total_timesteps    | 9000     |
# | train/                |          |
# |    entropy_loss       | -42.8    |
# |    explained_variance | -1.44    |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 1799     |
# |    policy_loss        | 36.5     |
# |    std                | 1.01     |
# |    value_loss         | 1.76     |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 98        |
# |    iterations         | 1900      |
# |    time_elapsed       | 96        |
# |    total_timesteps    | 9500      |
# | train/                |           |
# |    entropy_loss       | -42.8     |
# |    explained_variance | -0.000125 |
# |    learning_rate      | 0.0005    |
# |    n_updates          | 1899      |
# |    policy_loss        | -144      |
# |    std                | 1.01      |
# |    value_loss         | 12.9      |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 98       |
# |    iterations         | 2000     |
# |    time_elapsed       | 101      |
# |    total_timesteps    | 10000    |
# | train/                |          |
# |    entropy_loss       | -42.9    |
# |    explained_variance | 1.19e-07 |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 1999     |
# |    policy_loss        | -191     |
# |    std                | 1.01     |
# |    value_loss         | 23.6     |
# ------------------------------------
# ======A2C Validation from:  2020-10-01 to  2020-12-31
# A2C Sharpe Ratio:  0.24059739926334617
# ======PPO Training========
# {'ent_coef': 0.01, 'n_steps': 2048, 'learning_rate': 0.00025, 'batch_size': 64}
# Using cpu device
# Logging to tensorboard_log/ppo/ppo_252_1
# -----------------------------
# | time/              |      |
# |    fps             | 104  |
# |    iterations      | 1    |
# |    time_elapsed    | 19   |
# |    total_timesteps | 2048 |
# -----------------------------
# day: 2956, episode: 5
# begin_total_asset: 1000000.00
# end_total_asset: 3118781.85
# total_reward: 2118781.85
# total_cost: 355098.16
# total_trades: 85377
# Sharpe: 0.639
# =================================
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 101         |
# |    iterations           | 2           |
# |    time_elapsed         | 40          |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.019499615 |
# |    clip_fraction        | 0.25        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -42.7       |
# |    explained_variance   | -0.00431    |
# |    learning_rate        | 0.00025     |
# |    loss                 | 6.46        |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.0306     |
# |    std                  | 1.01        |
# |    value_loss           | 11.4        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 101         |
# |    iterations           | 3           |
# |    time_elapsed         | 60          |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.019399729 |
# |    clip_fraction        | 0.219       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -42.8       |
# |    explained_variance   | 0.00232     |
# |    learning_rate        | 0.00025     |
# |    loss                 | 8.06        |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.0269     |
# |    std                  | 1.01        |
# |    value_loss           | 45.7        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 100         |
# |    iterations           | 4           |
# |    time_elapsed         | 81          |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.016857766 |
# |    clip_fraction        | 0.197       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -42.8       |
# |    explained_variance   | 0.00261     |
# |    learning_rate        | 0.00025     |
# |    loss                 | 104         |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.0225     |
# |    std                  | 1.01        |
# |    value_loss           | 113         |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 100        |
# |    iterations           | 5          |
# |    time_elapsed         | 101        |
# |    total_timesteps      | 10240      |
# | train/                  |            |
# |    approx_kl            | 0.02251156 |
# |    clip_fraction        | 0.244      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -42.9      |
# |    explained_variance   | -0.0945    |
# |    learning_rate        | 0.00025    |
# |    loss                 | 5.09       |
# |    n_updates            | 40         |
# |    policy_gradient_loss | -0.0281    |
# |    std                  | 1.01       |
# |    value_loss           | 17.9       |
# ----------------------------------------
# ======PPO Validation from:  2020-10-01 to  2020-12-31
# PPO Sharpe Ratio:  0.26424408461192406
# ======DDPG Training========
# {'buffer_size': 100000, 'learning_rate': 5e-06, 'batch_size': 64}
# Using cpu device
# ...
# | time/                 |          |
# |    fps                | 97       |
# |    iterations         | 100      |
# |    time_elapsed       | 5        |
# |    total_timesteps    | 500      |
# | train/                |          |
# |    entropy_loss       | -42.8    |
# |    explained_variance | 0.158    |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 99       |
# |    policy_loss        | -10.8    |
# |    std                | 1.01     |
# |    value_loss         | 0.225    |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 97       |
# |    iterations         | 200      |
# |    time_elapsed       | 10       |
# |    total_timesteps    | 1000     |
# | train/                |          |
# |    entropy_loss       | -42.9    |
# |    explained_variance | 0.00111  |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 199      |
# |    policy_loss        | -52.4    |
# |    std                | 1.01     |
# |    value_loss         | 1.72     |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 97       |
# |    iterations         | 300      |
# |    time_elapsed       | 15       |
# |    total_timesteps    | 1500     |
# | train/                |          |
# |    entropy_loss       | -42.9    |
# |    explained_variance | 0.0899   |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 299      |
# |    policy_loss        | -190     |
# |    std                | 1.01     |
# |    value_loss         | 22.2     |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 97       |
# |    iterations         | 400      |
# |    time_elapsed       | 20       |
# |    total_timesteps    | 2000     |
# | train/                |          |
# |    entropy_loss       | -42.9    |
# |    explained_variance | 0.0596   |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 399      |
# |    policy_loss        | 78.2     |
# |    std                | 1.01     |
# |    value_loss         | 4.28     |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 97       |
# |    iterations         | 500      |
# |    time_elapsed       | 25       |
# |    total_timesteps    | 2500     |
# | train/                |          |
# |    entropy_loss       | -42.9    |
# |    explained_variance | 0.0158   |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 499      |
# |    policy_loss        | 295      |
# |    std                | 1.01     |
# |    value_loss         | 69.4     |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 98       |
# |    iterations         | 600      |
# |    time_elapsed       | 30       |
# |    total_timesteps    | 3000     |
# | train/                |          |
# |    entropy_loss       | -42.9    |
# |    explained_variance | 2.38e-07 |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 599      |
# |    policy_loss        | 351      |
# |    std                | 1.01     |
# |    value_loss         | 77.5     |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 97       |
# |    iterations         | 700      |
# |    time_elapsed       | 35       |
# |    total_timesteps    | 3500     |
# | train/                |          |
# |    entropy_loss       | -42.9    |
# |    explained_variance | 0.132    |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 699      |
# |    policy_loss        | 30.9     |
# |    std                | 1.01     |
# |    value_loss         | 1.75     |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 98       |
# |    iterations         | 800      |
# |    time_elapsed       | 40       |
# |    total_timesteps    | 4000     |
# | train/                |          |
# |    entropy_loss       | -43      |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 799      |
# |    policy_loss        | -155     |
# |    std                | 1.01     |
# |    value_loss         | 15       |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 98        |
# |    iterations         | 900       |
# |    time_elapsed       | 45        |
# |    total_timesteps    | 4500      |
# | train/                |           |
# |    entropy_loss       | -42.9     |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0005    |
# |    n_updates          | 899       |
# |    policy_loss        | 60.1      |
# |    std                | 1.01      |
# |    value_loss         | 7.32      |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 98       |
# |    iterations         | 1000     |
# |    time_elapsed       | 50       |
# |    total_timesteps    | 5000     |
# | train/                |          |
# |    entropy_loss       | -43      |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 999      |
# |    policy_loss        | -173     |
# |    std                | 1.01     |
# |    value_loss         | 26.7     |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 98       |
# |    iterations         | 1100     |
# |    time_elapsed       | 55       |
# |    total_timesteps    | 5500     |
# | train/                |          |
# |    entropy_loss       | -43      |
# |    explained_variance | 0.0439   |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 1099     |
# |    policy_loss        | 291      |
# |    std                | 1.01     |
# |    value_loss         | 53.5     |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 98       |
# |    iterations         | 1200     |
# |    time_elapsed       | 60       |
# |    total_timesteps    | 6000     |
# | train/                |          |
# |    entropy_loss       | -43      |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 1199     |
# |    policy_loss        | -276     |
# |    std                | 1.02     |
# |    value_loss         | 44.2     |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 98       |
# |    iterations         | 1300     |
# |    time_elapsed       | 66       |
# |    total_timesteps    | 6500     |
# | train/                |          |
# |    entropy_loss       | -43.1    |
# |    explained_variance | 1.19e-07 |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 1299     |
# |    policy_loss        | 63.2     |
# |    std                | 1.02     |
# |    value_loss         | 3.93     |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 98       |
# |    iterations         | 1400     |
# |    time_elapsed       | 71       |
# |    total_timesteps    | 7000     |
# | train/                |          |
# |    entropy_loss       | -43.1    |
# |    explained_variance | -0.153   |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 1399     |
# |    policy_loss        | 155      |
# |    std                | 1.02     |
# |    value_loss         | 12.5     |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 98       |
# |    iterations         | 1500     |
# |    time_elapsed       | 76       |
# |    total_timesteps    | 7500     |
# | train/                |          |
# |    entropy_loss       | -43.1    |
# |    explained_variance | 0.021    |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 1499     |
# |    policy_loss        | -147     |
# |    std                | 1.02     |
# |    value_loss         | 18.5     |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 98       |
# |    iterations         | 1600     |
# |    time_elapsed       | 81       |
# |    total_timesteps    | 8000     |
# | train/                |          |
# |    entropy_loss       | -43.1    |
# |    explained_variance | -0.04    |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 1599     |
# |    policy_loss        | -39.2    |
# |    std                | 1.02     |
# |    value_loss         | 2        |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 98       |
# |    iterations         | 1700     |
# |    time_elapsed       | 86       |
# |    total_timesteps    | 8500     |
# | train/                |          |
# |    entropy_loss       | -43.1    |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 1699     |
# |    policy_loss        | 1.04e+03 |
# |    std                | 1.02     |
# |    value_loss         | 748      |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 98       |
# |    iterations         | 1800     |
# |    time_elapsed       | 91       |
# |    total_timesteps    | 9000     |
# | train/                |          |
# |    entropy_loss       | -43.1    |
# |    explained_variance | 5.96e-08 |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 1799     |
# |    policy_loss        | 641      |
# |    std                | 1.02     |
# |    value_loss         | 442      |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 98       |
# |    iterations         | 1900     |
# |    time_elapsed       | 96       |
# |    total_timesteps    | 9500     |
# | train/                |          |
# |    entropy_loss       | -43.1    |
# |    explained_variance | 0.174    |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 1899     |
# |    policy_loss        | 89.6     |
# |    std                | 1.02     |
# |    value_loss         | 5.3      |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 98       |
# |    iterations         | 2000     |
# |    time_elapsed       | 101      |
# |    total_timesteps    | 10000    |
# | train/                |          |
# |    entropy_loss       | -43.1    |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 1999     |
# |    policy_loss        | 17.1     |
# |    std                | 1.02     |
# |    value_loss         | 3.47     |
# ------------------------------------
# ======A2C Validation from:  2020-12-31 to  2021-04-05
# A2C Sharpe Ratio:  0.2844711626769106
# ======PPO Training========
# {'ent_coef': 0.01, 'n_steps': 2048, 'learning_rate': 0.00025, 'batch_size': 64}
# Using cpu device
# Logging to tensorboard_log/ppo/ppo_315_1
# -----------------------------
# | time/              |      |
# |    fps             | 104  |
# |    iterations      | 1    |
# |    time_elapsed    | 19   |
# |    total_timesteps | 2048 |
# -----------------------------
# day: 3019, episode: 5
# begin_total_asset: 1000000.00
# end_total_asset: 3716326.00
# total_reward: 2716326.00
# total_cost: 371773.81
# total_trades: 87486
# Sharpe: 0.732
# =================================
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 101         |
# |    iterations           | 2           |
# |    time_elapsed         | 40          |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.017180324 |
# |    clip_fraction        | 0.245       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -42.6       |
# |    explained_variance   | -0.00599    |
# |    learning_rate        | 0.00025     |
# |    loss                 | 3.99        |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.021      |
# |    std                  | 1           |
# |    value_loss           | 12.7        |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 100        |
# |    iterations           | 3          |
# |    time_elapsed         | 60         |
# |    total_timesteps      | 6144       |
# | train/                  |            |
# |    approx_kl            | 0.02010864 |
# |    clip_fraction        | 0.213      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -42.7      |
# |    explained_variance   | -0.00984   |
# |    learning_rate        | 0.00025    |
# |    loss                 | 17.7       |
# |    n_updates            | 20         |
# |    policy_gradient_loss | -0.0237    |
# |    std                  | 1.01       |
# |    value_loss           | 59.4       |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 100         |
# |    iterations           | 4           |
# |    time_elapsed         | 81          |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.017463852 |
# |    clip_fraction        | 0.193       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -42.8       |
# |    explained_variance   | 0.00067     |
# |    learning_rate        | 0.00025     |
# |    loss                 | 12.2        |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.0233     |
# |    std                  | 1.01        |
# |    value_loss           | 31.1        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 100         |
# |    iterations           | 5           |
# |    time_elapsed         | 102         |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.025499437 |
# |    clip_fraction        | 0.263       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -42.8       |
# |    explained_variance   | -0.0494     |
# |    learning_rate        | 0.00025     |
# |    loss                 | 5.25        |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.0297     |
# |    std                  | 1.01        |
# |    value_loss           | 11.5        |
# -----------------------------------------
# ======PPO Validation from:  2020-12-31 to  2021-04-05
# PPO Sharpe Ratio:  0.24413364370768548
# ======DDPG Training========
# {'buffer_size': 100000, 'learning_rate': 5e-06, 'batch_size': 64}
# Using cpu device
# Logging to tensorboard_log/ddpg/ddpg_315_1
# day: 3019, episode: 10
# begin_total_asset: 1000000.00
# end_total_asset: 5987767.37
# total_reward: 4987767.37
# total_cost: 1747.75
# total_trades: 45732
# Sharpe: 0.847
# =================================
# ---------------------------------
# | time/              |          |
# |    episodes        | 4        |
# |    fps             | 52       |
# |    time_elapsed    | 230      |
# |    total timesteps | 12080    |
# | train/             |          |
# |    actor_loss      | 36.5     |
# |    critic_loss     | 288      |
# |    learning_rate   | 5e-06    |
# |    n_updates       | 9060     |
# ---------------------------------
# ======DDPG Validation from:  2020-12-31 to  2021-04-05
# ======Best Model Retraining from:  2009-01-01 to  2021-04-05
# ======Trading from:  2021-04-05 to  2021-07-02
# Ensemble Strategy took:  30.585842645168306  minutes

# %%
df_summary
# Out:
#   Iter   Val Start     Val End Model Used A2C Sharpe PPO Sharpe DDPG Sharpe
# 0  126  2020-04-02  2020-07-02        A2C   0.168125  0.0429579    0.153355
# 1  189  2020-07-02  2020-10-01       DDPG  0.0874467   0.114086    0.353985
# 2  252  2020-10-01  2020-12-31        PPO   0.240597   0.264244    0.263392
# 3  315  2020-12-31  2021-04-05       DDPG   0.284471   0.244134    0.316364

# %% [markdown]
# <a id='6'></a>
# # Part 7: Backtest Our Strategy
# Backtesting plays a key role in evaluating the performance of a trading strategy. Automated backtesting tool is preferred because it reduces the human error. We usually use the Quantopian pyfolio package to backtest our trading strategies. It is easy to use and consists of various individual plots that provide a comprehensive image of the performance of a trading strategy.

# %%
unique_trade_date = processed[(processed.date > val_test_start)&(processed.date <= val_test_end)].date.unique()

# %%
df_trade_date = pd.DataFrame({'datadate':unique_trade_date})

df_account_value=pd.DataFrame()
for i in range(rebalance_window+validation_window, len(unique_trade_date)+1,rebalance_window):
    temp = pd.read_csv('results/account_value_trade_{}_{}.csv'.format('ensemble',i))
    df_account_value = df_account_value.append(temp,ignore_index=True)
sharpe=(252**0.5)*df_account_value.account_value.pct_change(1).mean()/df_account_value.account_value.pct_change(1).std()
print('Sharpe Ratio: ',sharpe)
df_account_value=df_account_value.join(df_trade_date[validation_window:].reset_index(drop=True))
# Out:
# Sharpe Ratio:  1.8901515193256386

# %%
df_account_value.head()
# Out:
#    account_value        date  daily_return    datadate
# 0   1.000000e+06  2020-07-02           NaN  2020-07-02
# 1   1.001307e+06  2020-07-06      0.001307  2020-07-06
# 2   9.986224e+05  2020-07-07     -0.002681  2020-07-07
# 3   9.998617e+05  2020-07-08      0.001241  2020-07-08
# 4   9.946994e+05  2020-07-09     -0.005163  2020-07-09

# %%
# %matplotlib inline
df_account_value.account_value.plot()

# %% [markdown]
# <a id='6.1'></a>
# ## 7.1 BackTestStats
# pass in df_account_value, this information is stored in env class

# %%
print("==============Get Backtest Results===========")
now = datetime.datetime.now().strftime('%Y%m%d-%Hh%M')

perf_stats_all = backtest_stats(account_value=df_account_value)
perf_stats_all = pd.DataFrame(perf_stats_all)
# Out:
# ==============Get Backtest Results===========
# Annual return          0.331599
# Cumulative returns     0.331599
# Annual volatility      0.158855
# Sharpe ratio           1.890152
# Calmar ratio           2.987902
# Stability              0.916779
# Max drawdown          -0.110981
# Omega ratio            1.389877
# Sortino ratio          2.855865
# Skew                        NaN
# Kurtosis                    NaN
# Tail ratio             1.004685
# Daily value at risk   -0.018822
# dtype: float64

# %%
#baseline stats
print("==============Get Baseline Stats===========")
baseline_df = get_baseline(
        ticker="^DJI", 
        start = df_account_value.loc[0,'date'],
        end = df_account_value.loc[len(df_account_value)-1,'date'])

stats = backtest_stats(baseline_df, value_col_name = 'close')
# Out:
# ==============Get Baseline Stats===========
# [*********************100%***********************]  1 of 1 completed
# Shape of DataFrame:  (251, 8)
# Annual return          0.337432
# Cumulative returns     0.335890
# Annual volatility      0.146098
# Sharpe ratio           2.072078
# Calmar ratio           3.778308
# Stability              0.944970
# Max drawdown          -0.089308
# Omega ratio            1.411593
# Sortino ratio          3.102218
# Skew                        NaN
# Kurtosis                    NaN
# Tail ratio             1.078766
# Daily value at risk   -0.017205
# dtype: float64

# %% [markdown]
# <a id='6.2'></a>
# ## 7.2 BackTestPlot

# %%
print("==============Compare to DJIA===========")
# %matplotlib inline
# S&P 500: ^GSPC
# Dow Jones Index: ^DJI
# NASDAQ 100: ^NDX
backtest_plot(df_account_value, 
             baseline_ticker = '^DJI', 
             baseline_start = df_account_value.loc[0,'date'],
             baseline_end = df_account_value.loc[len(df_account_value)-1,'date'])
# Out:
# ==============Compare to DJIA===========
# [*********************100%***********************]  1 of 1 completed
# Shape of DataFrame:  (251, 8)
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;"><th>Start date</th><td colspan=2>2020-07-02</td></tr>
#     <tr style="text-align: right;"><th>End date</th><td colspan=2>2021-06-30</td></tr>
#     <tr style="text-align: right;"><th>Total months</th><td colspan=2>11</td></tr>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Backtest</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Annual return</th>
#       <td>32.4%</td>
#     </tr>
#     <tr>
#       <th>Cumulative returns</th>
#       <td>32.2%</td>
#     </tr>
#     <tr>
#       <th>Annual volatility</th>
#       <td>15.9%</td>
#     </tr>
#     <tr>
#       <th>Sharpe ratio</th>
#       <td>1.85</td>
#     </tr>
#     <tr>
#       <th>Calmar ratio</th>
#       <td>2.92</td>
#     </tr>
#     <tr>
#       <th>Stability</th>
#       <td>0.92</td>
#     </tr>
#     <tr>
#       <th>Max drawdown</th>
#       <td>-11.1%</td>
#     </tr>
#     <tr>
#       <th>Omega ratio</th>
#       <td>1.38</td>
#     </tr>
#     <tr>
#       <th>Sortino ratio</th>
#       <td>2.79</td>
#     </tr>
#     <tr>
#       <th>Skew</th>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>Kurtosis</th>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>Tail ratio</th>
#       <td>1.00</td>
#     </tr>
#     <tr>
#       <th>Daily value at risk</th>
#       <td>-1.9%</td>
#     </tr>
#     <tr>
#       <th>Alpha</th>
#       <td>-0.00</td>
#     </tr>
#     <tr>
#       <th>Beta</th>
#       <td>0.98</td>
#     </tr>
#   </tbody>
# </table>
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-33-28783090d2f2> in <module>()
#       7              baseline_ticker = '^DJI',
#       8              baseline_start = df_account_value.loc[0,'date'],
# ----> 9              baseline_end = df_account_value.loc[len(df_account_value)-1,'date'])
#
# /content/drive/My Drive/ColabNotebooks/myFinRL/finrl/plot.py in backtest_plot(account_value, baseline_start, baseline_end, baseline_ticker, value_col_name)
#      59     with pyfolio.plotting.plotting_context(font_scale=1.1):
#      60         pyfolio.create_full_tear_sheet(
# ---> 61             returns=test_returns, benchmark_rets=baseline_returns, set_context=False
#      62         )
#      63
#
# /usr/local/lib/python3.7/dist-packages/pyfolio/tears.py in create_full_tear_sheet(returns, positions, transactions, market_data, benchmark_rets, slippage, live_start_date, sector_mappings, bayesian, round_trips, estimate_intraday, hide_positions, cone_std, bootstrap, unadjusted_returns, style_factor_panel, sectors, caps, shares_held, volumes, percentile, turnover_denom, set_context, factor_returns, factor_loadings, pos_in_dollars, header_rows, factor_partitions)
#     209         turnover_denom=turnover_denom,
#     210         header_rows=header_rows,
# --> 211         set_context=set_context)
#     212
#     213     create_interesting_times_tear_sheet(returns,
#
# /usr/local/lib/python3.7/dist-packages/pyfolio/plotting.py in call_w_context(*args, **kwargs)
#      52                 return func(*args, **kwargs)
#      53         else:
# ---> 54             return func(*args, **kwargs)
#      55     return call_w_context
#      56
#
# /usr/local/lib/python3.7/dist-packages/pyfolio/tears.py in create_returns_tear_sheet(returns, positions, transactions, live_start_date, cone_std, benchmark_rets, bootstrap, turnover_denom, header_rows, return_fig)
#     502                              header_rows=header_rows)
#     503
# --> 504     plotting.show_worst_drawdown_periods(returns)
#     505
#     506     vertical_sections = 11
#
# /usr/local/lib/python3.7/dist-packages/pyfolio/plotting.py in show_worst_drawdown_periods(returns, top)
#    1662     """
#    1663
# -> 1664     drawdown_df = timeseries.gen_drawdown_table(returns, top=top)
#    1665     utils.print_table(
#    1666         drawdown_df.sort_values('Net drawdown in %', ascending=False),
#
# /usr/local/lib/python3.7/dist-packages/pyfolio/timeseries.py in gen_drawdown_table(returns, top)
#    1006         df_drawdowns.loc[i, 'Peak date'] = (peak.to_pydatetime()
#    1007                                             .strftime('%Y-%m-%d'))
# -> 1008         df_drawdowns.loc[i, 'Valley date'] = (valley.to_pydatetime()
#    1009                                               .strftime('%Y-%m-%d'))
#    1010         if isinstance(recovery, float):
#
# AttributeError: 'numpy.int64' object has no attribute 'to_pydatetime'
